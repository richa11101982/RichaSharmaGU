# %% [markdown]
# #Description
# This notebook analyzes and visualize housing data.

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='7dLGkMaEYSIfqBK2x36jZ9dE7dOw4iEGM1E8fqf2ikFn',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.eu.cloud-object-storage.appdomain.cloud')

bucket = 'richafirstlabwork-donotdelete-pr-102jzzrubnnlvl'
object_key = 'HousingStockTables.xlsx'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']

df_data_0 = pd.read_excel(body.read())
df_data_0.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN  Table 4-1.  Change in Number of Housing Units ...
# 1         NaN                                                NaN
# 2         NaN                                             County
# 3         NaN                                                NaN
# 4         NaN                                              Adams
#
#                 Unnamed: 2  Unnamed: 3                          Unnamed: 4
# 0                      NaN         NaN                                 NaN
# 1                      NaN         NaN                                 NaN
# 2  Number of Housing Units         NaN  Change in Number\nof Housing Units
# 3                     2010      2018.0                                 NaN
# 4                    12983     12932.0                           -0.003928
